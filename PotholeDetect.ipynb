# %%
# !nvidia-smi
# Out:
# Thu May 15 21:01:07 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             43W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %% [markdown]
# We've obtained our training data, now we must make sure our data is ready to use

# %%
# !unzip -q /content/data.zip -d /content/custom_data

# %% [markdown]
# Next we install the Ultralytics library in this Google Colab instance. This library is used to train the YOLO model.

# %%
# !pip install ultralytics

# %%
# !yolo detect train data=/content/custom_data/pothole_dataset_v8/pothole.yaml model=yolo11n.pt epochs=20 imgsz=512
# Out:
# Ultralytics 8.3.135 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...
